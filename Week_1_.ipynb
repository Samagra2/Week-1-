# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Alex"
age = 21
city = "Mumbai"

print(name)
print(age)
print(city)
# Out:
# Alex
# 21
# Mumbai

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
first_name = "Samagra"
last_name = "Gupta"

full_name = first_name + " " + last_name
print(full_name)
# Out:
# Samagra Gupta

# %%
favorite_foods = ["Pizza", "Burger", "Pasta", "Ice Cream"]

print(favorite_foods)
print("First food:", favorite_foods[0])
print("Last food:", favorite_foods[-1])
# Out:
# ['Pizza', 'Burger', 'Pasta', 'Ice Cream']
# First food: Pizza
# Last food: Ice Cream

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello", name)
print("You are", age, "years old")
# Out:
# Enter your name: Samagra Gupta
# Enter your age: 22
# Hello Samagra Gupta
# You are 22 years old

# %%
name = input("What is your name? ")
age = input("How old are you? ")

print(f"Hello {name}, you are {age} years old.")
# Out:
# What is your name? Samagra Gupta
# How old are you? 22
# Hello Samagra Gupta , you are 22 years old.

# %%
# Week 1 Project: Personal Introduction Program
# Beginner Friendly Python Code

name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")
city = input("Which city do you live in? ")

print("\n🎉 Welcome", name, "! 🎉")
print(f"You are {age} years old.")
print(f"You live in {city}.")
print(f"You love {hobby}.")
print("Nice to meet you! 😊")
# Out:
# What is your name? Samagra Gupta
# How old are you? 22
# What is your favorite hobby? Playing Badminton and Studying Finance
# Which city do you live in? Kanpur
#
# 🎉 Welcome Samagra Gupta  ! 🎉
# You are 22 years old.
# You live in Kanpur .
# You love Playing Badminton and Studying Finance .
# Nice to meet you! 😊
